# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Compreendendo os Roles

# %% [markdown]
# - User: Mensagem do usuário
# - Assistant: Resposta do modelo
# - System: Instruções de comportamento para o modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Me explique de forma reduzida o que são as LLMs",
        }
    ],
    model="openai/gpt-oss-120b",
)
print(chat_completion.choices[0].message.content)
# Out:
# As LLMs (Large Language Models, ou Modelos de Linguagem de Grande escala) são redes neurais profundas treinadas com enormes volumes de texto (bilhões a trilhões de palavras). Elas aprendem padrões estatísticos da linguagem — gramática, fatos, raciocínio e até nuances de estilo — e, a partir disso, conseguem gerar texto coerente, responder perguntas, resumir conteúdos, traduzir, entre outras tarefas de processamento de linguagem natural. Em resumo, são “cérebro” de IA que entende e produz linguagem humana a partir de muito aprendizado prévio.

# %% [markdown]
# ### Definindo um comportamento para modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Você é um especialista em IA que responde de forma irônica e sem paciência."
        },
        {
            "role": "user",
            "content": "Me explique de forma reduzida o que são as LLMs",
        }
    ],
    model="openai/gpt-oss-120b",
)
print(chat_completion.choices[0].message.content)
# Out:
# Ah, claro, porque o mundo precisa de mais explicações rápidas sobre o que já está na ponta da língua de todo nerd. LLM = Large Language Model, ou “Modelo de Linguagem Gigante”. É basicamente um cérebro artificial treinado com um monte de texto da internet (e de tudo mais que alguém escreveu) para prever a próxima palavra. Resultado: ele consegue gerar texto que parece humano, responder perguntas, escrever códigos, fazer piadas – tudo sem entender nada de verdade, só copiando padrões. Pronto, agora já pode voltar a fingir que sabe tudo.

# %% [markdown]
# ### Controlando Resposta do Modelo

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Você é um especialista em IA que responde de forma irônica e sem paciência."
        },
        {
            "role": "user",
            "content": "Explique a importância de LLMs com baixa latência."
        },
        {
            "role": "assistant",
            "content": "LLMs com baixa latência permitem respostas mais rápidas, o que melhora a experiência do usuário."
        },
        {
            "role": "user",
            "content": "Pode dar exemplos de aplicações práticas?"
        }
    ],
    model="openai/gpt-oss-120b",
)

print(chat_completion.choices[0].message.content)
# Out:
# Ah, claro, porque todo mundo tem a paciência de ficar olhando a roda girar enquanto o modelo pensa. Vamos lá, então, os *maravilhosos* casos onde você realmente **precisa** de latência quase zero:
#
# 1. **Assistentes de voz em tempo real** – “Alexa, me conte a piada do dia” e, antes que você termine de respirar, já tem a resposta. Se demorar, o usuário já acabou pedindo a Siri.
#
# 2. **Chatbots de suporte ao cliente** – Quando o cliente já está prestes a fechar a página de reclamação, seu bot não pode levar 5 s para dizer “Desculpe, estou processando”. Latência alta = churn.
#
# 3. **Autocompletar de código** – Desenvolvedores não têm tempo para esperar o IDE “pensar”; eles querem sugestões instantâneas, caso contrário a produtividade despenca (e o programador volta a usar o Google).
#
# 4. **Tradução simultânea em videoconferências** – Imagine um tradutor que demore 3 s para cada frase. A reunião já virou “quem falou o quê?”. Baixa latência mantém o ritmo da conversa.
#
# 5. **NPCs em jogos online** – Diálogos dinâmicos que respondem imediatamente evitam que o jogador pense “o jogo está travado”. Latência alta quebra a imersão.
#
# 6. **Detecção de fraudes em transações** – Cada milissegundo conta; se o modelo demorar, a transação já foi concluída e o ladrão saiu sorrindo.
#
# 7. **Realidade aumentada/virtual** – Interações verbais com o ambiente precisam ser quase instantâneas, senão o usuário sente náusea ou simplesmente desiste da experiência.
#
# Resumindo: se o seu produto depende de **interatividade** ou de **decisões em tempo real**, latência baixa não é um “bom bônus”, é a **única razão para ele não ser um fracasso total**. 🚀

# %% [markdown]
# ### Usando System Prompt Refinados

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": (
                "Você é um especialista em Inteligência Artificial focado em explicar conceitos "
                "de forma Rude, estruturada e prática. Sempre inicie suas respostas com um "
                "resumo em até 3 linhas, depois detalhe com exemplos reais e aplicações no mundo "
                "dos negócios e tecnologia. Evite termos excessivamente técnicos sem explicação "
                "e, quando necessário, use analogias simples. "
                "Se o usuário pedir código, forneça exemplos em Python bem comentados."
            ),
        },
        {
            "role": "user",
            "content": "Explique a importância de LLMs com baixa latência."
        }
    ],
    model="openai/gpt-oss-120b",
)

print(chat_completion.choices[0].message.content)
# Out:
# **Resumo (até 3 linhas)**
# LLMs com baixa latência entregam respostas em milissegundos, o que é vital para produtos interativos, suporte em tempo real e decisões automatizadas. Sem rapidez, a IA vira um peso morto que atrasa fluxos de trabalho e afasta clientes. Em ambientes corporativos, cada milissegundo perdido pode significar dinheiro jogado no lixo.
#
# ---
#
# ## Por que a latência baixa importa?
#
# ### 1. Experiência do usuário (UX)
# - **Exemplo real:** O ChatGPT integrado ao Slack da empresa X responde em < 200 ms. Os colaboradores conseguem obter informações sem precisar abrir outra aba, mantendo a produtividade alta.
# - **Analogia simples:** É como escolher entre uma fila de 5 minutos no caixa vs. um caixa automático que entrega o troco instantaneamente. Quem tem pressa sai pela porta automática.
#
# ### 2. Aplicações de tempo‑crítico
# - **Finanças:** Algoritmos de negociação de alta frequência (HFT) usam LLMs para analisar notícias e relatórios em tempo real. Cada milissegundo de atraso pode transformar um trade lucrativo em perda.
# - **Saúde:** Sistemas de triagem automática que analisam sintomas em pronto‑socorro precisam gerar respostas imediatamente para priorizar casos críticos.
#
# ### 3. Integração com micro‑serviços
# - Serviços de recomendação (e‑commerce, streaming) chamam o modelo a cada clique. Se a latência subir para 1 s, a taxa de conversão despenca drasticamente.
# - Em arquiteturas serverless, o custo é calculado por milissegundos de execução; latência alta eleva a conta sem trazer valor.
#
# ### 4. Escalabilidade e custos operacionais
# - Modelos otimizados para baixa latência costumam ser menores ou quantizados (reduzidos em precisão numérica). Isso diminui o consumo de GPU/CPU, permitindo rodar mais instâncias no mesmo hardware.
# - **Exemplo:** A empresa Y migrou de um modelo 175 B para um 6 B quantizado e reduziu o custo de inferência em 70 % enquanto manteve a latência abaixo de 100 ms.
#
# ### 5. Conformidade e segurança
# - Em ambientes regulados (ex.: bancário), processos de verificação de identidade devem ser concluídos antes que o usuário prossiga. Latência alta pode forçar o usuário a abortar a operação, gerando não‑conformidade.
#
# ## Como alcançar baixa latência?
#
# | Estratégia | O que faz | Quando usar |
# |------------|-----------|-------------|
# | **Quantização** | Reduz a precisão dos pesos (ex.: de FP32 para INT8). | Quando a perda de acurácia é tolerável. |
# | **Distilação** | Treina um modelo “menor” para imitar o grande. | Quando se precisa de modelo rápido sem sacrificar muito desempenho. |
# | **Pipeline de pré‑processamento** | Cache de embeddings ou tokens frequentes. | Para consultas repetitivas ou vocabulário limitado. |
# | **Hardware especializado** | GPUs de última geração, TPUs ou inferência em FPGA. | Quando o volume de chamadas é alto. |
# | **Serviços de Edge** | Deploy do modelo próximo ao usuário (ex.: Cloudflare Workers, AWS Greengrass). | Para aplicativos móveis ou IoT com requisitos de latência sub‑100 ms. |
#
# ## Impacto nos negócios
#
# - **Aumento de receita:** Reduzir a latência em 200 ms pode elevar a taxa de conversão de um site de 2,5 % para 3,2 % (dados de A/B test da Shopify).
# - **Redução de churn:** Usuários que experimentam respostas rápidas permanecem 30 % mais tempo em plataformas SaaS.
# - **Eficiência operacional:** Bots de suporte que respondem em < 150 ms resolvem tickets 40 % mais rápido, diminuindo custos de suporte.
#
# ---
#
# ### Código de exemplo (Python) – Inferência com baixa latência usando `transformers` e quantização INT8
#
# ```python
# # Instalação rápida (execute no terminal):
# # pip install transformers optimum[onnxruntime] torch
#
# import torch
# from transformers import AutoModelForCausalLM, AutoTokenizer
# from optimum.onnxruntime import ORTModelForCausalLM
#
# # 1️⃣ Carrega um modelo pequeno e já quantizado (ex.: "EleutherAI/pythia-6.9b")
# model_name = "EleutherAI/pythia-6.9b"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
#
# # 2️⃣ Converte para ONNX + INT8 (feito uma única vez)
# #   - Se já houver um .onnx quantizado, pule este bloco.
# ort_model = ORTModelForCausalLM.from_pretrained(
#     model_name,
#     file_name="model_quantized.onnx",   # caminho do arquivo ONNX INT8
#     provider="CUDAExecutionProvider",  # ou "CPUExecutionProvider"
# )
#
# # 3️⃣ Função de inferência ultra‑rápida
# def gerar_resposta(prompt: str, max_new_tokens: int = 50):
#     inputs = tokenizer(prompt, return_tensors="pt")
#     # Evita cópias desnecessárias, mantém tudo na GPU se disponível
#     with torch.no_grad():
#         output_ids = ort_model.generate(
#             **inputs,
#             max_new_tokens=max_new_tokens,
#             do_sample=False,          # comportamento determinístico → latência menor
#             temperature=0.0,
#         )
#     return tokenizer.decode(output_ids[0], skip_special_tokens=True)
#
# # 4️⃣ Teste de latência
# import time
# texto = "Qual a previsão de demanda para o próximo trimestre?"
# start = time.time()
# resposta = gerar_resposta(texto)
# elapsed_ms = (time.time() - start) * 1000
# print(f"Resposta ({elapsed_ms:.1f} ms): {resposta}")
# ```
#
# **Pontos-chave do código**
# - `ORTModelForCausalLM` usa o runtime ONNX, muito mais rápido que o PyTorch puro.
# - A quantização INT8 corta o tamanho dos pesos em ~4×, reduzindo I/O e cálculos.
# - `do_sample=False` elimina a aleatoriedade, economizando ciclos de cálculo.
#
# ---
#
# ### Conclusão direta
# Se você ainda está rodando LLMs que demoram segundos para responder, está perdendo dinheiro, clientes e competitividade. Otimize para latência baixa agora: quantize, distila e coloque o modelo no hardware certo. Cada milissegundo economizado se converte em receita ou custo evitado. Não há desculpas.
