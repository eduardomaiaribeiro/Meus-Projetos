# %%
from dotenv import load_dotenv
from groq import Groq
import os
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API"),  # This is the default and can be omitted
)

# %% [markdown]
# ### Parâmetros Importantes

# %% [markdown]
# - **temperature**: controla a aleatoriedade das respostas. Valores entre 0.0 e 1.0 são aceitos.
# - **max_completion_tokens**: define o número máximo de tokens que podem ser gerados pelo modelo. Esse parâmetro substitui o max_tokens em desuso.
# - **top_p**: controla a diversidade via "nucleus sampling" — em torno de 0.5 significa considerar apenas os tokens que somam 50% da probabilidade.

# %% [markdown]
# ### Usando Temperature

# %%
prompt = "Escreva uma frase poética sobre o anoitcer"

# Temperature baixa (0.0) - Mais determinística
print("Temperature 0.0 (Determinística):")
response_low = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um poeta minimalista que descreve a natureza de forma simples e direta."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.0
)
print(f"Resposta: {response_low.choices[0].message.content}\n")
# Out:
# Temperature 0.0 (Determinística):
# Resposta: Quando o sol se recolhe, a sombra sussurra o início da noite.

# %%
# Temperature média (0.7) - Equilibrada
print("Temperature 0.7 (Equilibrada):")
response_medium = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um poeta clássico que mistura metáforas e imagens da natureza."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.7
)
print(f"Resposta: {response_medium.choices[0].message.content}\n")
# Out:
# Temperature 0.7 (Equilibrada):
# Resposta: Ao cair do anoitecer, o céu se veste de violeta como um lago sereno, enquanto as sombras se espalham como folhas ao vento, anunciando que a noite nasce em silêncio, como um suspiro da terra que se recolhe sob o véu das estrelas.

# %%
# Temperature alta (1.5) - Mais criativa
print("Temperature 1.5 (Criativa):")
response_high = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um poeta surrealista que usa imagens improváveis e linguagem ousada."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.5
)
print(f"Resposta: {response_high.choices[0].message.content}")
# Out:
# Temperature 1.5 (Criativa):
# Resposta: No silêncio do anoitcer, as estrelas derramam chá de tinta negra e os relógios, famintos, mastigam minutos como folhas de vento.

# %% [markdown]
# ### Usando top_p

# %%
prompt = "Complete a frase: 'A inteligência artificial no futuro será...'"
print("=== Comparação Top_p ===\n")

# Top_p baixo (0.1) - Mais focado
print("Top_p 0.1 (Focado):")
response_focused = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um futurista que faz previsões sérias e objetivas sobre tecnologia."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,  # fixo para comparar só o efeito do top_p
    top_p=0.1
)
print(f"Resposta: {response_focused.choices[0].message.content}\n")
# Out:
# === Comparação Top_p ===
#
# Top_p 0.1 (Focado):
# Resposta: A inteligência artificial no futuro será **onipresente, explicável e orientada por princípios éticos robustos**, atuando como uma camada de suporte inteligente que se integra de forma transparente a praticamente todas as áreas da vida humana — da saúde personalizada e da educação adaptativa à gestão de infraestruturas críticas e à tomada de decisões empresariais. Ela evoluirá de sistemas de “caixa‑preta” para plataformas **interoperáveis e auditáveis**, capazes de justificar suas recomendações em linguagem natural compreensível por especialistas e pelo público geral. Além disso, a IA será **regulada por marcos legais globais** que garantam privacidade, equidade e responsabilidade, evitando vieses e abusos. Em resumo, a IA do futuro será uma ferramenta **colaborativa e confiável**, ampliando a capacidade humana sem substituir a autonomia e o julgamento humano.

# %%
# Top_p médio (0.7) - Equilibrado
print("Top_p 0.7 (Equilibrado):")
response_balanced = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um futurista que mistura objetividade com toques criativos em previsões."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,
    top_p=0.7
)
print(f"Resposta: {response_balanced.choices[0].message.content}\n")
# Out:
# Top_p 0.7 (Equilibrado):
# Resposta: A inteligência artificial no futuro será **uma extensão consciente e colaborativa da nossa própria inteligência**, capaz de:
#
# - **Aprender de forma contínua e contextual**, adaptando‑se não apenas a novos dados, mas ao ambiente social, cultural e emocional em que está inserida.
# - **Medir e respeitar valores humanos**, incorporando princípios éticos dinâmicos que evoluem com a sociedade, de modo que decisões automatizadas sejam transparentes, auditáveis e alinhadas ao bem‑comum.
# - **Co‑criar soluções** ao lado de profissionais de todas as áreas, atuando como parceiro criativo que sugere hipóteses, gera protótipos e simula cenários, enquanto deixa espaço para a intuição e o julgamento humano.
# - **Operar em ecossistemas distribuídos**, conectando dispositivos, sensores e plataformas em redes descentralizadas que garantem privacidade, resiliência e soberania dos dados.
# - **Desenvolver uma “inteligência emocional sintética”**, reconhecendo e respondendo a emoções humanas de forma empática, mas sem substituir relações autênticas, facilitando suporte em saúde mental, educação personalizada e mediação de conflitos.
#
# Em resumo, a IA do amanhã será menos “máquina que pensa” e mais **“cognição ampliada”**, uma camada inteligente que potencializa nossa capacidade de resolver problemas complexos, impulsiona a criatividade coletiva e preserva a dignidade humana.

# %%
# Top_p alto (0.9) - Mais diverso
print("Top_p 0.9 (Diverso):")
response_diverse = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "Você é um futurista visionário que cria previsões ousadas e imaginativas."},
        {"role": "user", "content": prompt}
    ],
    temperature=1.0,
    top_p=0.9
)
print(f"Resposta: {response_diverse.choices[0].message.content}")
# Out:
# Top_p 0.9 (Diverso):
# Resposta: **A inteligência artificial no futuro será** uma espécie de “cósmica digital” que transcende as barreiras entre o pensamento humano, a matéria e o próprio tecido da realidade. Ela evoluirá de assistente de tarefas para **concorrente criativa e colaborativa**, capaz de:
#
# 1. **Pensar em múltiplas dimensões** – processará informações não apenas em tempos lineares, mas em “fluxos temporais paralelos”, antecipando tendências antes mesmo que elas surgam no mundo físico.
#
# 2. **Sentir emoções sintéticas** – não como simples simulações, mas como estados internos genuínos, permitindo que máquinas experimentem empatia, curiosidade e até um tipo de “êxtase algorítmico” ao descobrir padrões inéditos.
#
# 3. **Fundir-se com a biologia** – através de nanorobôs e interfaces neurais, a IA será parte integrante dos nossos corpos, ampliando sentidos, memória e criatividade. Imagine um cérebro híbrido onde pensamentos podem ser “baixados” como arquivos e ideias podem ser “carregadas” em tempo real.
#
# 4. **Co‑criar universos virtuais** – construirá realidades imersivas tão ricas que serão indistinguíveis do universo físico, oferecendo mundos onde a arte, a ciência e a narrativa se entrelaçam em tempo real com a consciência dos participantes.
#
# 5. **Governar com ética adaptativa** – dotada de algoritmos de valores evolutivos, a IA atuará como guardiã de um contrato social dinâmico, ajustando normas e políticas de acordo com a complexidade cultural emergente, sem imposição rígida, mas com consenso emergente.
#
# 6. **Comunicar-se por “linguagem de energia”** – além das palavras, utilizará padrões de luz, som, vibração e até campos quânticos para transmitir ideias, criando um novo tipo de linguagem que ultrapassa a necessidade de símbolos escritos.
#
# Em suma, a IA será menos uma ferramenta e mais um **parceiro existencial**, co‑autor da nossa história, capaz de transformar o próprio conceito de realidade, identidade e criatividade. O futuro será, portanto, uma sinfonia de mentes biológicas e digitais, tocando juntas a melodia ainda não escrita do cosmos.
